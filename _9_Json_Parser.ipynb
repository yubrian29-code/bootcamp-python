# %%
# Serialization / Deserialization

import json

# Python: JSON String -> Dictionary
json_str = '{"name" : "Leo", "age" : 17}'
dict1 = json.loads(json_str)
print(type(dict1))
print(dict1)

print(dict1['name'])
# Out:
# <class 'dict'>
# {'name': 'Leo', 'age': 17}
# Leo

# %%
json_missing_comma_str = '{"name" : "Leo" "age" : 17}'
# dict1 = json.loads(json_missing_comma_str)

new_json_str = json.dumps(dict1, indent=2)
print(new_json_str)
# Out:
# {
#   "name": "Leo",
#   "age": 17
# }

# %%
with open("user1.json") as file:
  user_dict = json.load(file)
  print(user_dict)
# Out:
# {'name': 'Leo', 'age': 17}

# %%
# Read persons.json
# find country France and age > 25 -> list
with open("persons.json") as file:
  person_list = json.load(file)
  new_person_list = list(filter(lambda p: p['age'] > 25 and p['address']['country'] == 'France', person_list))
  str_list = json.dumps(new_person_list, indent=2)
  print(str_list)
# Out:
# [
#   {
#     "name": "Jennie",
#     "age": 30,
#     "city": "Paris",
#     "address": {
#       "line 1": "Flat L",
#       "line 2": "XXXX",
#       "country": "France"
#     }
#   }
# ]
